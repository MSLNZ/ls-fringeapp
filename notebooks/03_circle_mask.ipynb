# %% [markdown]
# given an array array same shape as image where points on gauge are 1 others 0
# add a circle of zeros

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw

# %%
from ls_fringeapp import fringeprocess as fp

# %%
img_array = np.zeros((1108, 1108))

# %%
xygb = np.array([[ 146., 180.],
       [931., 180.,],
       [931., 946.]])

# %%
bwo, co, ro, bwi, ci, ri, ccen, rcen = fp.gbroif(img_array, xygb)

# %%
fig = plt.figure(figsize=(6, 6), dpi=80)
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.imshow(bwi, cmap=matplotlib.cm.gray)

# %%
mask = Image.fromarray(bwi.astype('bool'))

# %%
mask
# Out:
# <PIL.Image.Image image mode=1 size=1108x1108>

# %%
draw = ImageDraw.Draw(mask)
draw.ellipse((400, 400, 700, 700), fill = 'black', outline ='black')

# %%
mask
# Out:
# <PIL.Image.Image image mode=1 size=1108x1108>
